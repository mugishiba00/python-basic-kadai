# %% [markdown]
# <a href="https://colab.research.google.com/github/mugishiba00/python-basic-kadai/blob/main/kadai__008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ver = 15
if ver % 3 == 0 and ver % 5 == 0:
    print("FizzBuzz")
elif ver % 3 == 0:
  print("Fizz")
elif ver % 5 == 0:
  print("Buzz")
else:
  print(ver)
# Out:
# FizzBuzz
